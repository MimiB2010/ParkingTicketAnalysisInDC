# %%
# Import Dependencies
import pandas as pd
import requests
import json

# %%
   # Create a reference the CSV file desired
csv_path = "Parking_Violations_Issued_in_December_2018.csv"

# Read the CSV into a Pandas DataFrame
Parking2018 = pd.read_csv(csv_path)

# Print the first five rows of data to the screen
Parking2018.head()
# Out:
#            X          Y  OBJECTID  ROWID_  DAY_OF_WEEK  HOLIDAY  WEEK_OF_YEAR  \
# 0 -77.026516  38.897354   5373144     NaN          NaN      NaN           NaN
# 1 -77.053032  38.899362   5373145     NaN          NaN      NaN           NaN
# 2 -77.031951  38.908045   5373146     NaN          NaN      NaN           NaN
# 3 -77.027555  38.901335   5373147     NaN          NaN      NaN           NaN
# 4 -77.007473  38.902527   5373148     NaN          NaN      NaN           NaN
#
#    MONTH_OF_YEAR  ISSUE_TIME VIOLATION_CODE  \
# 0            NaN         NaN           P034
# 1            NaN         NaN           P003
# 2            NaN         NaN           P385
# 3            NaN         NaN           P281
# 4            NaN         NaN           P025
#
#                                VIOLATION_DESCRIPTION  \
# 0                     METER, FAIL TO DEPOSIT PAYMENT
# 1   RESIDENTIAL PERMIT PKING BEYOND LIMIT W/O PERMIT
# 2  STOPPING, STANDING OR PARKING VEHICLE IN BIKE ...
# 3         FAIL TO DISPLAY A MULTISPACE METER RECEIPT
# 4        PARK LESS THAN 40 FEET FROM AN INTERSECTION
#
#                               LOCATION RP_PLATE_STATE  BODY_STYLE  ADDRESS_ID  \
# 0        1000 BLOCK F ST NW SOUTH SIDE             DC         NaN      813477
# 1     800 BLOCK NEW HAMPSHIRE AVE NW *             DC         NaN      811580
# 2      BLOCK 1400 14TH ST NW WEST SIDE             DC         NaN      802156
# 3      1200 BLOCK EYE ST NW NORTH SIDE             DC         NaN      801091
# 4        UNIT BLOCK K ST NE SOUTH SIDE             DC         NaN      808361
#
#    STREETSEGID  XCOORD  YCOORD         TICKET_ISSUE_DATE
# 0      11599.0  397700  136611  2018-12-07T10:09:00.000Z
# 1       9940.0  395400  136835  2018-12-07T10:48:00.000Z
# 2       1804.0  397229  137798  2018-12-31T15:28:00.000Z
# 3        919.0  397610  137053  2018-12-06T20:59:00.000Z
# 4       7159.0  399352  137185  2018-12-07T13:03:00.000Z

# %%
Parking2018 = Parking2018.drop(columns=["ROWID_","DAY_OF_WEEK",
                          "BODY_STYLE","HOLIDAY",
                          "WEEK_OF_YEAR","MONTH_OF_YEAR","ISSUE_TIME"])

Parking2018.head()
# Out:
#            X          Y  OBJECTID VIOLATION_CODE  \
# 0 -77.026516  38.897354   5373144           P034
# 1 -77.053032  38.899362   5373145           P003
# 2 -77.031951  38.908045   5373146           P385
# 3 -77.027555  38.901335   5373147           P281
# 4 -77.007473  38.902527   5373148           P025
#
#                                VIOLATION_DESCRIPTION  \
# 0                     METER, FAIL TO DEPOSIT PAYMENT
# 1   RESIDENTIAL PERMIT PKING BEYOND LIMIT W/O PERMIT
# 2  STOPPING, STANDING OR PARKING VEHICLE IN BIKE ...
# 3         FAIL TO DISPLAY A MULTISPACE METER RECEIPT
# 4        PARK LESS THAN 40 FEET FROM AN INTERSECTION
#
#                               LOCATION RP_PLATE_STATE  ADDRESS_ID  \
# 0        1000 BLOCK F ST NW SOUTH SIDE             DC      813477
# 1     800 BLOCK NEW HAMPSHIRE AVE NW *             DC      811580
# 2      BLOCK 1400 14TH ST NW WEST SIDE             DC      802156
# 3      1200 BLOCK EYE ST NW NORTH SIDE             DC      801091
# 4        UNIT BLOCK K ST NE SOUTH SIDE             DC      808361
#
#    STREETSEGID  XCOORD  YCOORD         TICKET_ISSUE_DATE
# 0      11599.0  397700  136611  2018-12-07T10:09:00.000Z
# 1       9940.0  395400  136835  2018-12-07T10:48:00.000Z
# 2       1804.0  397229  137798  2018-12-31T15:28:00.000Z
# 3        919.0  397610  137053  2018-12-06T20:59:00.000Z
# 4       7159.0  399352  137185  2018-12-07T13:03:00.000Z
