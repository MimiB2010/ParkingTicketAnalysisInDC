# %%
# Import Dependencies
import pandas as pd
import requests
import json
import gmaps
from config import gkey
from config1 import zipkey
import random
from pprint import pprint
import os
import glob
gmaps.configure(api_key=gkey)

# %%
#    # Create a reference the CSV file desired
# csv_path = "Parking_Violations_Issued_in_December_2018.csv"

# # Read the CSV into a Pandas DataFrame
# ParkingDec2018 = pd.read_csv(csv_path)

# # Print the first five rows of data to the screen
# ParkingDec2018 = ParkingDec2018.drop(columns=["ROWID_","DAY_OF_WEEK",
#                           "BODY_STYLE","HOLIDAY",
#                           "WEEK_OF_YEAR","MONTH_OF_YEAR","ISSUE_TIME"])
# ParkingDec2018.head()

# %%
# ParkingDec2018 = ParkingDec2018.round({"X": 3, "Y":3})
# ParkingDec2018.head()

# %%
# ParkingDec2018_Grouped = ParkingDec2018.groupby(["X","Y"]).count()
# ParkingDec2018_Grouped = ParkingDec2018_Grouped.reset_index()

# # Store latitude and longitude in locations
# locationsDec2018 = ParkingDec2018_Grouped[["Y", "X"]]

# # Fill NaN values and convert to float
# countDec2018 = ParkingDec2018_Grouped["OBJECTID"].astype(float)
# ParkingDec2018_Grouped

# %%
# fig = gmaps.figure()

# # Create heat layer
# heat_layer = gmaps.heatmap_layer(locationsDec2018, weights=countDec2018, dissipating=False, max_intensity=300, point_radius=.0015)

# # # Add layer
# fig.add_layer(heat_layer)

# # Display figure
# fig

# %%
# # Read the CSV into a Pandas DataFrame
# ParkingSept2018 = pd.read_csv("Parking_Violations_Issued_in_September_2018.csv")

# # Print the first five rows of data to the screen
# ParkingSept2018 = ParkingSept2018.drop(columns=["ROWID_","DAY_OF_WEEK",
#                           "BODY_STYLE","HOLIDAY",
#                           "WEEK_OF_YEAR","MONTH_OF_YEAR","ISSUE_TIME"])
# ParkingSept2018_Grouped = ParkingSept2018.groupby(["X","Y"]).count()
# ParkingSept2018_Grouped = ParkingSept2018_Grouped.reset_index()

# # Store latitude and longitude in locations
# locationsSept2018 = ParkingSept2018_Grouped[["Y", "X"]]

# # Fill NaN values and convert to float
# countSept2018 = ParkingSept2018_Grouped["OBJECTID"].astype(float)

# fig = gmaps.figure()

# # Create heat layer
# heat_layer = gmaps.heatmap_layer(locationsSept2018, weights=countSept2018, dissipating=False, max_intensity=300, point_radius=.0015)

# # # Add layer
# fig.add_layer(heat_layer)

# # Display figure
# fig

# %%
# # Read the CSV into a Pandas DataFrame
# ParkingJune2018 = pd.read_csv("Parking_Violations_Issued_in_June_2018.csv")

# # Print the first five rows of data to the screen
# ParkingJune2018 = ParkingJune2018.drop(columns=["ROWID_","DAY_OF_WEEK",
#                           "BODY_STYLE","HOLIDAY",
#                           "WEEK_OF_YEAR","MONTH_OF_YEAR","ISSUE_TIME"])
# ParkingJune2018_Grouped = ParkingJune2018.groupby(["X","Y"]).count()
# ParkingJune2018_Grouped = ParkingJune2018_Grouped.reset_index()

# # Store latitude and longitude in locations
# locationsJune2018 = ParkingJune2018_Grouped[["Y", "X"]]

# # Fill NaN values and convert to float
# countJune2018 = ParkingJune2018_Grouped["OBJECTID"].astype(float)

# fig = gmaps.figure()

# # Create heat layer
# heat_layer = gmaps.heatmap_layer(locationsJune2018, weights=countJune2018, dissipating=False, max_intensity=300, point_radius=.0015)

# # # Add layer
# fig.add_layer(heat_layer)

# # Display figure
# fig

# %%
# # Read the CSV into a Pandas DataFrame
# ParkingMarch2018 = pd.read_csv("Parking_Violations_Issued_in_March_2018.csv")

# # Print the first five rows of data to the screen
# ParkingMarch2018 = ParkingMarch2018.drop(columns=["ROWID_","DAY_OF_WEEK",
#                           "BODY_STYLE","HOLIDAY",
#                           "WEEK_OF_YEAR","MONTH_OF_YEAR","ISSUE_TIME"])
# ParkingMarch2018_Grouped = ParkingMarch2018.groupby(["X","Y"]).count()
# ParkingMarch2018_Grouped = ParkingMarch2018_Grouped.reset_index()

# # Store latitude and longitude in locations
# locationsMarch2018 = ParkingMarch2018_Grouped[["Y", "X"]]

# # Fill NaN values and convert to float
# countMarch2018 = ParkingMarch2018_Grouped["OBJECTID"].astype(float)

# fig = gmaps.figure()

# # Create heat layer
# heat_layer = gmaps.heatmap_layer(locationsMarch2018, weights=countMarch2018, dissipating=False, max_intensity=300, point_radius=.0015)

# # # Add layer
# fig.add_layer(heat_layer)

# # Display figure
# fig

# %%
# # Read the CSV into a Pandas DataFrame
# ParkingDec2017 = pd.read_csv("Parking_Violations_Issued_in_December_2017.csv")

# # Print the first five rows of data to the screen
# ParkingDec2017 = ParkingDec2017.drop(columns=["ROWID_","DAY_OF_WEEK",
#                           "BODY_STYLE","HOLIDAY",
#                           "WEEK_OF_YEAR","MONTH_OF_YEAR","ISSUE_TIME"])
# ParkingDec2017_Grouped = ParkingDec2017.groupby(["X","Y"]).count()
# ParkingDec2017_Grouped = ParkingDec2017_Grouped.reset_index()

# # Store latitude and longitude in locations
# locationsDec2017 = ParkingDec2017_Grouped[["Y", "X"]]

# # Fill NaN values and convert to float
# countDec2017 = ParkingDec2017_Grouped["OBJECTID"].astype(float)

# fig = gmaps.figure()

# # Create heat layer
# heat_layer = gmaps.heatmap_layer(locationsDec2017, weights=countDec2017, dissipating=False, max_intensity=300, point_radius=.0015)

# # # Add layer
# fig.add_layer(heat_layer)

# # Display figure
# fig

# %%
# ParkingDec2016 = pd.read_csv("Parking_Violations_Issued_in_December_2016.csv")

# # Print the first five rows of data to the screen
# ParkingDec2016 = ParkingDec2016.drop(columns=["ROWID_","DAY_OF_WEEK",
#                           "BODY_STYLE","HOLIDAY",
#                           "WEEK_OF_YEAR","MONTH_OF_YEAR","ISSUE_TIME"])
# ParkingDec2016_Grouped = ParkingDec2016.groupby(["X","Y"]).count()
# ParkingDec2016_Grouped = ParkingDec2016_Grouped.reset_index()

# # Store latitude and longitude in locations
# locationsDec2016 = ParkingDec2016_Grouped[["Y", "X"]]

# # Fill NaN values and convert to float
# countDec2016 = ParkingDec2016_Grouped["OBJECTID"].astype(float)

# fig = gmaps.figure()

# # Create heat layer
# heat_layer = gmaps.heatmap_layer(locationsDec2016, weights=countDec2016, dissipating=False, max_intensity=300, point_radius=.0015)

# # # Add layer
# fig.add_layer(heat_layer)

# # Display figure
# fig

# %%
# ParkingDec2018_2dec = ParkingDec2018.round({"X": 2, "Y":2})
# ParkingDec2018_2dec_Grouped = ParkingDec2018_2dec.groupby(["X","Y"]).count()
# ParkingDec2018_2dec_Grouped = ParkingDec2018_2dec_Grouped.reset_index()
# ParkingDec2018_2dec_Grouped["zipcode"] = 0.0

# Sample = ParkingDec2018_2dec_Grouped.sample(n=4)
# Sample = Sample.reset_index(drop=True)


# for index, row in Sample.iterrows():
#     url = "https://api.zip-codes.com/ZipCodesAPI.svc/1.0/FindZipCodesInRadius/ByLatLon?"
#     lat = row["Y"]
#     long = row["X"]
#     query_url = f"{url}latitude={lat}&longitude={long}&minimumradius=0&maximumradius=35&key=1DNE1DQVJDNWE0AIALVT"
#     zip_response = requests.get(query_url).json()
#     Sample.loc[index, "zipcode"]  = zip_response["DataList"][0]['Code']
#     print(Sample["zipcode"])

 #   https://api.zip-codes.com/ZipCodesAPI.svc/1.0/FindZipCodesInRadius/
  #      ByLatLon?latitude=38.90&longitude=-77.05&minimumradius=0&maximumradius=1&key=OWKXBSRX0W2KUC3RPTQM

# %%
# for index, row in ParkingDec2018_2dec_Grouped.iterrows():
#     url = "https://api.zip-codes.com/ZipCodesAPI.svc/1.0/FindZipCodesInRadius/ByLatLon?"
#     lat = row["Y"]
#     long = row["X"]
#     query_url = f"{url}latitude={lat}&longitude={long}&minimumradius=0&maximumradius=35&key=1DNE1DQVJDNWE0AIALVT"
#     zip_response = requests.get(query_url).json()
#     ParkingDec2018_2dec_Grouped.loc[index, "zipcode"]  = zip_response["DataList"][0]['Code']
#     Google_

# %%
# ParkingDec2018_2dec_Grouped
# ParkingDec2018_2dec_Grouped.to_csv("Parking_Dec_Grouped_with_zips.csv")

# %%
# ParkingDec2018_2dec_Grouped["Google_zipcode"] = " "

# for index, row in ParkingDec2018_2dec_Grouped.iterrows():
#     lat = row["Y"]
#     long = row["X"]
#     location = f'{lat},{long}'
#     G_url = f'https://maps.googleapis.com/maps/api/geocode/json?latlng={location}&key={gkey}'    
#     zipcode_response = requests.get(G_url).json()
#     ParkingDec2018_2dec_Grouped.loc[index, "Google_zipcode"]  = zipcode_response["results"][0]["address_components"][5]['long_name']

# %%
# pprint(zipcode_response)

# %%
# ParkingDec2018_2dec_Grouped

# %%
#import Data
path = "ParkingData/2018Data" 
all_files = glob.glob(path + "/*.csv")
li=[]

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

parking_data = pd.concat(li, axis=0, ignore_index=True)

parking_data = parking_data.round({"X": 3, "Y":3})
parking_data.head()

len(parking_data)
parking_data
# Out:
#               X       Y  OBJECTID  ROWID_  DAY_OF_WEEK  HOLIDAY  WEEK_OF_YEAR  \
# 0       -77.009  38.873   5359102     NaN          NaN      NaN           NaN
# 1       -77.034  38.902   5359103     NaN          NaN      NaN           NaN
# 2       -77.027  38.919   5359104     NaN          NaN      NaN           NaN
# 3       -77.027  38.919   5359105     NaN          NaN      NaN           NaN
# 4       -77.038  38.906   5359106     NaN          NaN      NaN           NaN
# 5       -77.036  38.906   5359107     NaN          NaN      NaN           NaN
# 6       -77.037  38.935   5361122     NaN          NaN      NaN           NaN
# 7       -76.984  38.915   5361123     NaN          NaN      NaN           NaN
# 8       -77.028  38.963   5361124     NaN          NaN      NaN           NaN
# 9       -76.936  38.888   5361125     NaN          NaN      NaN           NaN
# 10      -77.012  38.903   5361126     NaN          NaN      NaN           NaN
# ...

# %%
# Print the first five rows of data to the screen
parking_data = parking_data.drop(columns=["ROWID_","DAY_OF_WEEK",
                          "BODY_STYLE","HOLIDAY",
                          "WEEK_OF_YEAR","MONTH_OF_YEAR","ISSUE_TIME"])
parking_data_Grouped = parking_data.groupby(["X","Y"]).count()
parking_data_Grouped = parking_data_Grouped.reset_index()

# Store latitude and longitude in locations
locations2016 = parking_data_Grouped[["Y", "X"]]

# Fill NaN values and convert to float
count2016 = parking_data_Grouped["OBJECTID"].astype(float)

fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations2016, weights=count2016, dissipating=False, max_intensity=3000, point_radius=.001)

# # Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# parking_data_Grouped_sorted = parking_data_Grouped.sort_values(by=["OBJECTID"], ascending=False)

# %%
# Parking_greater_than500 = parking_data_Grouped_sorted[parking_data_Grouped_sorted['OBJECTID']>500]
# Parking_greater_than500 = Parking_greater_than200.reset_index(drop=True)


# # Store latitude and longitude in locations
# locations_500_2016 = Parking_greater_than500[["Y", "X"]]

# # Fill NaN values and convert to float
# count_500_2016 = Parking_greater_than500["OBJECTID"].astype(float)

# fig = gmaps.figure()

# # Create heat layer
# heat_layer = gmaps.heatmap_layer(locations_500_2016, weights=count_500_2016, dissipating=False, max_intensity=2000, point_radius=.001)

# # # Add layer
# fig.add_layer(heat_layer)

# # Display figure
# fig

# %%
# Out:
# Figure(layout=FigureLayout(height='420px'))
